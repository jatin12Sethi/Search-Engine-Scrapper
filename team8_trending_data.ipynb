# %%
import requests
import json
url = "https://api.dataforseo.com/v3/keywords_data/google_trends/explore/live"

payload="[{\"date_from\":\"2022-12-04\", \"date_to\":\"2022-12-12\", \"category_code\":0, \"type\":\"web\", \"keywords\":[\"quantum physics\"], \"language_code\":\"en\"}]"
headers = {
	'Authorization': 'Basic c2V0aGlqYXRpbjkyOEBnbWFpbC5jb206OGFkY2Y1OTUzNjFkODgxZA==',
	'Content-Type': 'application/json'
}

response = requests.request("POST", url, headers=headers, data=payload)

print(response.text)
# Out:
# {
#     "version": "0.1.20221214",
#     "status_code": 20000,
#     "status_message": "Ok.",
#     "time": "3.1062 sec.",
#     "cost": 0.009,
#     "tasks_count": 1,
#     "tasks_error": 0,
#     "tasks": [
#         {
#             "id": "12280857-4771-0173-0000-f69be4a93982",
#             "status_code": 20000,
#             "status_message": "Ok.",
#             "time": "3.0419 sec.",
#             "cost": 0.009,
#             "result_count": 1,
#             "path": [
#                 "v3",
#                 "keywords_data",
#                 "google_trends",
#                 "explore",
#                 "live"
#             ],
#             "data": {
#                 "api": "keywords_data",
#                 "function": "explore",
#                 "se": "google_trends",
#                 "date_from": "2022-12-04",
#                 "date_to": "2022-12-12",
#                 "category_code": 0,
#                 "type": "web",
#                 "keywords": [
# ...

# %%
import requests

url = "https://google-trends-us.p.rapidapi.com/get-trending-results"

headers = {
	"X-RapidAPI-Key": "0117e95be4msh2045477c5381566p114651jsn1fefda27f0e3",
	"X-RapidAPI-Host": "google-trends-us.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers)
print(response.text)
# Out:
# {"data":["missing texas a&amp;m student found dead","ted lasso season 3","st louis demetrious johnson","is dunkin donuts open christmas day","taylor heinicke","plumbing frozen pipes","plane crashes santa monica","planet fitness holiday hours christmas","franco harris pittsburgh steelers","cnn ehlers danlos syndrome"],"message":"Trending Items Fetched."}

# %%
#need a api-key for authentication as its paid :"SEOBOT API"
import requests

headers = {
    'Content-Type': 'application/json',
    'Authorization': 'access-token',
}

json_data = {
    'image_url': 'https://images.example.com/image.jgp',
    'download': False,
}

response = requests.post('https://api.seobot.com:11115/google/images', headers=headers, json=json_data)
print(response.text)
# Out:
# {"error":"authorization failed for token: access-token","requests_remaining":0,"result":null}

# %%
pip install pytrends
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for pytrends: filename=pytrends-4.8.0-py3-none-any.whl size=16127 sha256=0680b6d94c408f5c58c9195ca19760b993106db2146b21d4df18f0daa33b56b7
#   Stored in directory: /root/.cache/pip/wheels/e8/78/c8/18d4f4804753e14416809b365773220c48b41fe5387f2bb6b9
# Successfully built pytrends
# ...

# %% [markdown]
# #visualization

# %%
# connect to google 

from pytrends.request import TrendReq

pytrends = TrendReq(hl='en-US', tz=360) 
kw_list = ["quantum physics"] # list of keywords to get data 

pytrends.build_payload(kw_list, cat=0, timeframe='today 12-m') 
#1 Interest over Time
data = pytrends.interest_over_time() 
data = data.reset_index() 


import plotly.express as px

fig = px.line(data, x="date", y=['quantum physics'], title='Keyword Web Search Interest Over Time')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data  = pytrends.related_queries()
print(data['quantum physics']['top'] )
# Out:
#                          query  value
# 0           quantum of physics    100
# 1              what is physics     53
# 2              what is quantum     52
# 3      what is quantum physics     50
# 4            quantum mechanics     45
# 5                    mechanics     44
# 6       quantum physics theory     30
# 7               quantum theory     30
# 8              quantum meaning     23
# 9      quantum physics meaning     23
# 10         quantum physics pdf     21
# 11                     science     13
# 12  quantum physics definition     13
# 13          quantum definition     13
# 14          physics definition     13
# 15        quantum physics book     13
# 16       quantum physics books     11
# 17            particle physics     11
# 18           quantum computing     10
# 19    what are quantum physics     10
# 20  quantum meaning in physics     10
# 21               quantum field      9
# 22           classical physics      9
# 23                   chemistry      8
# ...

# %%
import pandas as pd
keywords = pytrends.suggestions(keyword='quantum physics')
df = pd.DataFrame(keywords)
print(df)
# Out:
#              mid                                              title  \
# 0       /m/069dx                                  Quantum mechanics
# 1    /g/122_gfd3                                    quantum physics
# 2  /g/11j7b_pmvm  The Grand Biocentric Design: How Life Creates ...
# 3  /g/11h_11vh0m            By Quantum Physics: A Nightlife Venture
# 4  /g/11h_zbpst_       The Physics Book: Big Ideas Simply Explained
#
#                                                 type
# 0                                              Topic
# 1                                              Topic
# 2  Book by Bob Berman, Matej Pavšič, and Robert L...
# 3                                          2019 film
# 4                                               Book

# %%
# !pip install beautifulsoup4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
