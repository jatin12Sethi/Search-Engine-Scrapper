# %% [markdown]
# <a href="https://colab.research.google.com/github/jatin12Sethi/Search-Engine-Scrapper/blob/main/team8_trending_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **TEAM 8 SEARCH ENGINE SCRAPER**

# %%
pip install pytrends

# %%
from datetime import datetime
global counter
global req_time
counter = 1
now_time = datetime.now().strftime("%H:%M")
req_time = int(now_time[:2])*60 + int(now_time[3:])

# %%
import requests
import json
import html.parser
import time
import socket
from datetime import datetime

today_date = datetime.today().strftime("%Y-%m-%d")
one_yr_bef = today_date[:2] + str(int(today_date[2:4])-1) + today_date[4:]
inp=input("Enter a keyword \n")

class HTMLTextExtractor(html.parser.HTMLParser):
    def __init__(self):
        super(HTMLTextExtractor, self).__init__()
        self.result = [ ]

    def handle_data(self, d):
        self.result.append(d)

    def get_text(self):
        return ''.join(self.result)

def html_to_text(html):

    s = HTMLTextExtractor()
    s.feed(html)
    return s.get_text()

query_list = ['how','what','when','where','are', 'is', 'why', 'can']
search_query = inp
search_query_list = []
for i in query_list:
  search_query_list.append(i+" "+search_query)
for i in range(97,ord('z')+1):
  search_query_list.append(search_query + ' ' + chr(i))
#print(search_query_list)

# Dyanamic country code and language could be implemented
language = "en"
country_code ="IN"
###############################
client = "gws-wiz"
authuser = 0
params = {
    'q':search_query_list[4],
    'cp':3,
    'client':client,
    'hl':"{0}-{1}".format(language, country_code),
    'authuser':0,
    'dpr':1,
    }
headers = {
    'authority': 'ogs.google.com',
    'sec-ch-ua': '" Not A;Brand";v="99", "Chromium";v="98", "Google Chrome";v="98"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Chrome OS"',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (X11; CrOS x86_64 14388.52.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/98.0.4758.91 Safari/537.36',
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'x-chrome-connected': 'source=Chrome,mode=0,enable_account_consistency=true,supervised=false,consistency_enabled_by_default=false',
    'x-client-data': 'CJG2yQEIprbJAQipncoBCJbpygEIt6DLAQiTocsBCOvyywEInvnLAQiljswBCIGkzAE=',
    'sec-fetch-site': 'same-site',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-dest': 'iframe',
    'referer': 'https://www.google.com/',
    'accept-language': 'en-US,en;q=0.9',
    # Requests sorts cookies= alphabetically
    # 'cookie': 'SID=KgipsdC3Yxa9m7JCFiSf9ERCriYX3tio-sdln7YpWH15A05EkNn3lzEaOxsxKB_j73HZ8Q.; __Secure-1PSID=KgipsdC3Yxa9m7JCFiSf9ERCriYX3tio-sdln7YpWH15A05EDjjIiujZe5PuNwI0jKTIUQ.; __Secure-3PSID=KgipsdC3Yxa9m7JCFiSf9ERCriYX3tio-sdln7YpWH15A05EgV9PEOK8KcjRZ-uQ-V6-3A.; HSID=A4EPy3YgwJXM51l6-; SSID=Ay5kAM2fDjIkfmpCX; APISID=Akv6x6eGTTq5dDC0/AMwo4EQGB5jsZRP11; SAPISID=Xdgah6CYZtLA1H0L/AlykPZRaBrmcFhebU; __Secure-1PAPISID=Xdgah6CYZtLA1H0L/AlykPZRaBrmcFhebU; __Secure-3PAPISID=Xdgah6CYZtLA1H0L/AlykPZRaBrmcFhebU; OTZ=6519179_34_34__34_; SEARCH_SAMESITE=CgQIwZUB; 1P_JAR=2022-05-25-06; NID=511=Vl8RZrmSnFRPwPAlCvStF4RZ5FRWrRCOngQ0jhVt8Lw5f-p8a-PyCbT_XdrJERuW932YfBn2AWGB6D_Msimu6gIBgM0eI47WAtWtHAiz6A3E3WoU8AaiRhsUlw3K9VBHTkS-DEXd6AEU96t60oe-ZIj9A9XVT1WKKIUdAsmHY5qhgRuqwst2Yif6s98aIFy8vMaoZ3K6rgU6hQCFbBU06M-hgy-ByRuvhph2V79vJBWXeT9Rcbh__pRmGnfv3K8Bh2oYngp2inVqlNxgxdqaFOvsrJWpFWIuC9JFJkCEAg; OGPC=19022519-1:; AEC=AakniGO1bomcWh2W_Hjby5dk15zIQE-zegTw55ljJQPb_rcF9eh_q2bycyM; SIDCC=AJi4QfHXY7354Db5dHXtuotnTXiDpiZeT500CGU_-gH7aV4aUGXrj6lieYU4l6U2tvWfhMWShA; __Secure-3PSIDCC=AJi4QfHU6C6zb0AcfqPm0l553V_uOB4y_wjFuhXD24na1ABfq53RoHU4_h1gW3rOAw0WAYzt6g',
    }

resp = requests.get("https://www.google.com/complete/search", params = params, headers=headers)
#print(resp.json())


# Loop implemented to avoid multiple iteration for every query

for query_index in range(len(search_query_list)):
  params = {
    'q':search_query_list[query_index],
    'cp':3,
    'client':client,
    'hl':"{0}-{1}".format(language, country_code),
    'authuser':0,
    'dpr':1,
    }
  resp = requests.get("https://www.google.com/complete/search", params = params, headers=headers, timeout = 5)
  from posixpath import sep
  json_suggestions1 = resp.text.replace("window.google.ac.h(", "")
  json_suggestions1 =  json_suggestions1[:-1]
  try:
    final_tuple = json.loads(html_to_text(json_suggestions1.encode('ascii').decode('unicode-escape')))
  except:
      pass
  #print(final_tuple)
  if(query_index == 0):
    f = open("myfile.txt", "w")
  else:
    f = open("myfile.txt", "a")
  #print(final_tuple[0][0][0])
  #print(len(final_tuple[0]))

  list_of_outs = []

  for val in final_tuple[0]:
      no_of_vals = len(val)
      for n in range(no_of_vals):
          req_val = final_tuple[0][n][0]
          list_of_outs += [req_val]

  #print(list_of_outs)
  for values in list_of_outs:
      sp_val = values.split(' </b>')
      new = ' '.join(sp_val)
      if(new[-4:] != '</b>'):
          list_of_outs[list_of_outs.index(values)] = new
      else:
          list_of_outs[list_of_outs.index(values)] = new[:-4]

  list_of_outs = list(set(list_of_outs))
  list_of_outs.sort()

  ind = 0

  
  #list_of_outs[0][:len(search_query_list[query_index])]==search_query_list[query_index]

  qer = ' '.join(search_query_list[query_index].split(inp)).strip()

  if(len(qer)>1):
      if(qer in list_of_outs[0]):
          print('\n\033[1m'+search_query_list[query_index]+'\033[0m\n')
          for out in list_of_outs:
              if(out != search_query_list[query_index]):
                  print("\x1B[3m"+''.join(out.split('</b>'))+"\x1B[0m")
              # Is it necessary the below line?
              else:
                  pass
      else:
          print('\n\033[1m'+search_query_list[query_index]+'\033[0m\n')
          print("\x1B[3m"+'NO RESULTS FOUND'+"\x1B[0m")
  else:
      to_ch = list_of_outs[0].split(inp)[-1].strip()
      try:
        if(to_ch[0] == qer):
            print('\n\033[1m'+search_query_list[query_index]+'\033[0m\n')
            for out in list_of_outs:
                print("\x1B[3m"+''.join(out.split('</b>'))+"\x1B[0m")
        else:
            print('\n\033[1m'+search_query_list[query_index]+'\033[0m\n')
            print("\x1B[3m"+'NO RESULTS FOUND'+"\x1B[0m")
      except:
          pass

global counter
counter += 1

if(counter == 800):
    
    crt = datetime.now().strftime("%H:%M")
    req_crt = int(crt[:2])*60 + int(crt[3:])
    if(req_crt < req_time):
        counter = 0
        req_time = req_crt
    else:
        if((req_crt - req_time)//60 <3.5):
            time.sleep(150)
            req_time = req_crt
            counter = 1
        else:
            counter = 400
            req_time = req_crt

# connect to google 

from pytrends.request import TrendReq

hostname = socket.gethostname()    
IPAddr = socket.gethostbyname(hostname)

time.sleep(5)

try:
    pytrends = TrendReq(hl='en-US', tz=360, timeout=(10,25), retries = 2, backoff_factor=0.1)

except:
    pytrends = TrendReq(hl='en-US', tz=360, timeout=(10,25),proxies=['https://'+IPAddr,'https://34.203.233.13:80','https://35.201.123.31:880','https://174.70.1.210','https://139.162.252.174','https://204.2.218.145','https://130.41.101.105','https://85.92.119.65'], retries=3, backoff_factor=0.1, requests_args={'verify':False})

else:
    quit()

kw_list = [inp] # list of keywords to get data 

pytrends.build_payload(kw_list, cat=0, timeframe='today 12-m') 
try:
    data_for_related_topics = pytrends.related_topics()
    rising_title = list(data_for_related_topics[inp]['rising']['topic_title'])
    rising_type = list(data_for_related_topics[inp]['rising']['topic_type'])

    print("\n\n\033[1mRelated Topic Titles And Types With Rising Interest\033[0m\n\n")

    for i in range(len(rising_title)):
        print('\x1B[3m' + rising_title[i] + ' - ' + rising_type[i] + '\x1B[0m')

    top_title = list(data_for_related_topics[inp]['top']['topic_title'])
    top_type = list(data_for_related_topics[inp]['top']['topic_type'])

    print('\n\n\033[1mTop Searched Related Topic Titles and Types\033[0m\n\n')

    for i in range(len(top_title)):
        print('\x1B[3m' + top_title[i] + ' - ' + top_type[i] + '\x1B[0m')
except:
    pass

try:
    data_for_related_queries = pytrends.related_queries()
    rising_query = list(data_for_related_queries[inp]['rising']['query'])
    rising_query_val = list(data_for_related_queries[inp]['rising']['value'])

    print("\n\n\033[1mRelated Queries With Rising Interest And Their Search Values\033[0m\n\n")

    for i in range(len(rising_query)):
        print('\x1B[3m' + rising_query[i] + ' - ' + str(rising_query_val[i]) + '\x1B[0m')

    top_query = list(data_for_related_queries[inp]['top']['query'])
    top_query_val = list(data_for_related_queries[inp]['top']['value'])

    print('\n\n\033[1mTop Searched Related Queries And Search Values\033[0m\n\n')

    for i in range(len(top_query)):
        print('\x1B[3m' + top_query[i] + ' - ' + str(top_query_val[i]) + '\x1B[0m')

    print('\n\n')

except:
    pass

data = pytrends.interest_over_time() 
data = data.reset_index() 


import plotly.express as px

fig = px.line(data, x="date", y=inp, title='Keyword Web Search Interest Over Time')
fig.show()
# Out:
# Enter a keyword
# machine learning
# <ipython-input-2-c8f837edc746>:91: DeprecationWarning: invalid escape sequence '\/'
#   final_tuple = json.loads(html_to_text(json_suggestions1.encode('ascii').decode('unicode-escape')))
# how machine learning
#
# how does machine learning work
# how to become a machine learning engineer
# how to learn machine learning
#
# what machine learning
#
# what machine learning engineer do
# what machine learning model to use
#
# when machine learning
#
# when machine learning goes off the rails
# when machine learning invented
# when machine learning started
#
# where machine learning
#
# where machine learning can be used
# where machine learning is applied
# where machine learning is used
#
# are machine learning
#
# are genetic algorithms machine learning
# are machine learning and ai the same
# are neural networks machine learning
#
# is machine learning
#
# is machine learning ai
# is machine learning data science
# is machine learning hard
#
# why machine learning
#
# why learn machine learning
# why python for machine learning
#
# can machine learning
#
# cancer detection using machine learning
# cancer prediction using machine learning
# candidate elimination algorithm in machine learning
#
# machine learning a
#
# machine learning a probabilistic perspective
# machine learning ai
# machine learning algorithms
# machine learning applications
#
# machine learning b
#
# machine learning basics
# machine learning bias
# machine learning books
# machine learning bootcamp
#
# machine learning c
#
# machine learning certification
# machine learning conferences 2023
# machine learning course
#
# machine learning d
#
# machine learning datasets
# machine learning definition
# machine learning degree
# machine learning design patterns
#
# machine learning e
#
# machine learning engineer
# machine learning engineer jobs
# machine learning engineer salary
#
# machine learning f
#
# machine learning for beginners
# machine learning for dummies
# machine learning for kids
# machine learning for trading
#
# machine learning g
#
# machine learning games
# machine learning google
# machine learning gpu
#
# machine learning h
#
# machine learning hardware
# machine learning healthcare
# machine learning history
# machine learning hyperparameter
#
# machine learning i
#
# machine learning in healthcare
# machine learning in r
# machine learning internship
# machine learning interview questions
#
# machine learning j
#
# machine learning jobs
# machine learning jobs salary
# machine learning journal
#
# machine learning k
#
# machine learning kaggle
# machine learning kernel
# machine learning kevin murphy
# machine learning knn
#
# machine learning l
#
# machine learning language
# machine learning libraries
# machine learning linear regression
#
# machine learning m
#
# machine learning masters
# machine learning mastery
# machine learning meaning
# machine learning models
#
# machine learning n
#
# machine learning neural networks
# machine learning news
# machine learning nlp
#
# machine learning o
#
# machine learning online course
# machine learning operations
# machine learning optimization
# machine learning overfitting
#
# machine learning p
#
# machine learning pipeline
# machine learning project ideas
# machine learning projects
# machine learning python
#
# machine learning q
#
# machine learning quantum computing
# machine learning questions
# machine learning quiz
# machine learning quotes
#
# machine learning r
#
# machine learning reddit
# machine learning regression
# machine learning resume
#
# machine learning s
#
# machine learning salary
# machine learning software
# machine learning specialization
# machine learning system design
#
# machine learning t
#
# machine learning techniques
# machine learning tools
# machine learning tutorial
#
# machine learning u
#
# machine learning udemy
# machine learning university
# machine learning use cases
# machine learning uses
#
# machine learning v
#
# machine learning vs ai
# machine learning vs artificial intelligence
# machine learning vs deep learning
#
# machine learning w
#
# machine learning wikipedia
# machine learning with python
# machine learning with pytorch and scikit-learn
# machine learning with r
#
# machine learning x
#
# machine learning x and y
# machine learning xgboost
# machine learning xkcd
#
# machine learning y
#
# machine learning yearning
# machine learning yearning pdf
# machine learning youtube
#
# machine learning z
#
# machine learning zero shot
# machine learning zero to hero
# machine learning zoo
# machine learning zoomcamp
#
#
# Related Topic Titles And Types With Rising Interest
#
#
# Machine Learning for Kids: A Project-Based Introduction to Artificial Intelligence - Book by Dale Lane
# Google Scholar - Web site
# Linear regression - Topic
# Logistic function - Topic
# Support vector machine - Topic
# Ensemble learning - Topic
# Decision tree - Topic
# Column - Database
# Cluster analysis - Topic
# Random forest - Topic
# Naivety - Topic
# Linearity - Topic
# Logistic regression - Topic
# k-nearest neighbors algorithm - Topic
# Decision-making - Topic
# Kaggle - Data science company
# Confusion matrix - Topic
#
#
# Top Searched Related Topic Titles and Types
#
#
# Learning - Topic
# Data - Topic
# Artificial intelligence - Topic
# Python - Programming language
# Algorithm - Topic
# Intelligence - Topic
# Prediction - Topic
# Science - School category
# Deep learning - Topic
# Regression analysis - Topic
# Data science - Field of study
# Project - Topic
# Course - Education
# Statistical classification - Topic
# Engineer - Degree
# Data set - Topic
# Analysis - Topic
# used - Topic
# Artificial neural network - Topic
# Computer Application - Software classification
# GitHub - IT service management company
# GitHub - Software developer
# Supervised learning - Topic
# Neuron - Topic
# Linear regression - Topic
#
#
# Related Queries With Rising Interest And Their Search Values
#
#
# chatgpt - 16000
# llm machine learning - 4300
# designing machine learning systems - 600
# openai - 200
# machine learning javatpoint - 110
# a company wishes to begin the process of implementing a multi-party system and is looking for other companies with similar interests to join them. with blockchain, every organization sees the same data. what does this provide? - 100
# ieee xplore - 80
# overleaf - 80
# heart disease prediction using machine learning - 70
# scholar - 70
# machine learning roadmap - 70
# bayes theorem in machine learning - 60
# ensemble learning in machine learning - 60
# colab - 60
# google colab - 60
# dimensionality reduction in machine learning - 60
# linear regression machine learning - 60
# knn algorithm - 60
# knn algorithm in machine learning - 60
# eda machine learning - 60
# classification in machine learning - 60
# linear regression - 60
# inductive bias in machine learning - 60
# supervised learning in machine learning - 60
# feature extraction in machine learning - 50
#
#
# Top Searched Related Queries And Search Values
#
#
# what is machine learning - 100
# python - 88
# python machine learning - 88
# machine learning model - 60
# ai machine learning - 56
# ai - 53
# deep learning - 51
# machine learning deep learning - 50
# google machine learning - 47
# regression - 43
# regression machine learning - 43
# data science - 37
# artificial intelligence - 36
# which - 36
# machine learning classification - 34
# classification - 34
# ml - 33
# machine learning algorithms - 32
# machine learning meaning - 31
# machine learning pdf - 30
# machine learning engineer - 29
# machine learning course - 26
# machine learning models - 26
# regression in machine learning - 25
# ai and machine learning - 23
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="f11f59b8-48f4-4a0f-ad22-0a266f91f1c9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f11f59b8-48f4-4a0f-ad22-0a266f91f1c9")) {                    Plotly.newPlot(                        "f11f59b8-48f4-4a0f-ad22-0a266f91f1c9",                        [{"hovertemplate":"date=%{x}<br>machine learning=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2022-02-20T00:00:00","2022-02-27T00:00:00","2022-03-06T00:00:00","2022-03-13T00:00:00","2022-03-20T00:00:00","2022-03-27T00:00:00","2022-04-03T00:00:00","2022-04-10T00:00:00","2022-04-17T00:00:00","2022-04-24T00:00:00","2022-05-01T00:00:00","2022-05-08T00:00:00","2022-05-15T00:00:00","2022-05-22T00:00:00","2022-05-29T00:00:00","2022-06-05T00:00:00","2022-06-12T00:00:00","2022-06-19T00:00:00","2022-06-26T00:00:00","2022-07-03T00:00:00","2022-07-10T00:00:00","2022-07-17T00:00:00","2022-07-24T00:00:00","2022-07-31T00:00:00","2022-08-07T00:00:00","2022-08-14T00:00:00","2022-08-21T00:00:00","2022-08-28T00:00:00","2022-09-04T00:00:00","2022-09-11T00:00:00","2022-09-18T00:00:00","2022-09-25T00:00:00","2022-10-02T00:00:00","2022-10-09T00:00:00","2022-10-16T00:00:00","2022-10-23T00:00:00","2022-10-30T00:00:00","2022-11-06T00:00:00","2022-11-13T00:00:00","2022-11-20T00:00:00","2022-11-27T00:00:00","2022-12-04T00:00:00","2022-12-11T00:00:00","2022-12-18T00:00:00","2022-12-25T00:00:00","2023-01-01T00:00:00","2023-01-08T00:00:00","2023-01-15T00:00:00","2023-01-22T00:00:00","2023-01-29T00:00:00","2023-02-05T00:00:00"],"xaxis":"x","y":[87,84,91,92,93,90,90,84,97,97,89,100,90,87,83,87,90,89,84,81,81,84,78,81,77,76,87,80,82,82,89,94,86,92,89,85,87,93,99,88,93,94,92,81,71,83,87,88,91,97,90],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921" ...
