# %% [markdown]
# <a href="https://colab.research.google.com/github/jatin12Sethi/Search-Engine-Scrapper/blob/main/Web_Scrapper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***First 2 cells woud be executed only once and after that every time we need to search for something, all we have to do is to run the THIRD CELL.***

# %%
pip install pytrends
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pytrends in /usr/local/lib/python3.8/dist-packages (4.9.0)
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.8/dist-packages (from pytrends) (1.3.5)
# Requirement already satisfied: requests>=2.0 in /usr/local/lib/python3.8/dist-packages (from pytrends) (2.25.1)
# Requirement already satisfied: lxml in /usr/local/lib/python3.8/dist-packages (from pytrends) (4.9.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.25->pytrends) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.25->pytrends) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.25->pytrends) (2022.7.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.0->pytrends) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.0->pytrends) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.0->pytrends) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests>=2.0->pytrends) (1.24.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas>=0.25->pytrends) (1.15.0)

# %%
from datetime import datetime
import requests
import json
import html.parser
import time
import socket
from pytrends.request import TrendReq
import plotly.express as px

global counter
global req_time
counter = 1
now_time = datetime.now().strftime("%H:%M")
req_time = int(now_time[:2])*60 + int(now_time[3:])

def function_to_call_for_every_search():

    today_date = datetime.today().strftime("%Y-%m-%d")
    one_yr_bef = today_date[:2] + str(int(today_date[2:4])-1) + today_date[4:]
    inp=input("Enter a keyword => ")

    class HTMLTextExtractor(html.parser.HTMLParser):
        def __init__(self):
            super(HTMLTextExtractor, self).__init__()
            self.result = [ ]

        def handle_data(self, d):
            self.result.append(d)

        def get_text(self):
            return ''.join(self.result)

    def html_to_text(html):

        s = HTMLTextExtractor()
        s.feed(html)
        return s.get_text()

    query_list = ['how','what','when','where','are', 'is', 'why', 'can']
    search_query = inp
    search_query_list = []
    for i in query_list:
        search_query_list.append(i+" "+search_query)
    for i in range(97,ord('z')+1):
        search_query_list.append(search_query + ' ' + chr(i))
    #print(search_query_list)

    # Dyanamic country code and language could be implemented
    language = "en"
    country_code ="IN"
    ###############################
    client = "gws-wiz"
    authuser = 0
    params = {
        'q':search_query_list[4],
        'cp':3,
        'client':client,
        'hl':"{0}-{1}".format(language, country_code),
        'authuser':0,
        'dpr':1,
        }
    headers = {
        'authority': 'ogs.google.com',
        'sec-ch-ua': '" Not A;Brand";v="99", "Chromium";v="98", "Google Chrome";v="98"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Chrome OS"',
        'upgrade-insecure-requests': '1',
        'user-agent': 'Mozilla/5.0 (X11; CrOS x86_64 14388.52.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/98.0.4758.91 Safari/537.36',
        'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
        'x-chrome-connected': 'source=Chrome,mode=0,enable_account_consistency=true,supervised=false,consistency_enabled_by_default=false',
        'x-client-data': 'CJG2yQEIprbJAQipncoBCJbpygEIt6DLAQiTocsBCOvyywEInvnLAQiljswBCIGkzAE=',
        'sec-fetch-site': 'same-site',
        'sec-fetch-mode': 'navigate',
        'sec-fetch-dest': 'iframe',
        'referer': 'https://www.google.com/',
        'accept-language': 'en-US,en;q=0.9',
        # Requests sorts cookies= alphabetically
        # 'cookie': 'SID=KgipsdC3Yxa9m7JCFiSf9ERCriYX3tio-sdln7YpWH15A05EkNn3lzEaOxsxKB_j73HZ8Q.; __Secure-1PSID=KgipsdC3Yxa9m7JCFiSf9ERCriYX3tio-sdln7YpWH15A05EDjjIiujZe5PuNwI0jKTIUQ.; __Secure-3PSID=KgipsdC3Yxa9m7JCFiSf9ERCriYX3tio-sdln7YpWH15A05EgV9PEOK8KcjRZ-uQ-V6-3A.; HSID=A4EPy3YgwJXM51l6-; SSID=Ay5kAM2fDjIkfmpCX; APISID=Akv6x6eGTTq5dDC0/AMwo4EQGB5jsZRP11; SAPISID=Xdgah6CYZtLA1H0L/AlykPZRaBrmcFhebU; __Secure-1PAPISID=Xdgah6CYZtLA1H0L/AlykPZRaBrmcFhebU; __Secure-3PAPISID=Xdgah6CYZtLA1H0L/AlykPZRaBrmcFhebU; OTZ=6519179_34_34__34_; SEARCH_SAMESITE=CgQIwZUB; 1P_JAR=2022-05-25-06; NID=511=Vl8RZrmSnFRPwPAlCvStF4RZ5FRWrRCOngQ0jhVt8Lw5f-p8a-PyCbT_XdrJERuW932YfBn2AWGB6D_Msimu6gIBgM0eI47WAtWtHAiz6A3E3WoU8AaiRhsUlw3K9VBHTkS-DEXd6AEU96t60oe-ZIj9A9XVT1WKKIUdAsmHY5qhgRuqwst2Yif6s98aIFy8vMaoZ3K6rgU6hQCFbBU06M-hgy-ByRuvhph2V79vJBWXeT9Rcbh__pRmGnfv3K8Bh2oYngp2inVqlNxgxdqaFOvsrJWpFWIuC9JFJkCEAg; OGPC=19022519-1:; AEC=AakniGO1bomcWh2W_Hjby5dk15zIQE-zegTw55ljJQPb_rcF9eh_q2bycyM; SIDCC=AJi4QfHXY7354Db5dHXtuotnTXiDpiZeT500CGU_-gH7aV4aUGXrj6lieYU4l6U2tvWfhMWShA; __Secure-3PSIDCC=AJi4QfHU6C6zb0AcfqPm0l553V_uOB4y_wjFuhXD24na1ABfq53RoHU4_h1gW3rOAw0WAYzt6g',
        }

    resp = requests.get("https://www.google.com/complete/search", params = params, headers=headers)
    #print(resp.json())


    # Loop implemented to avoid multiple iteration for every query

    for query_index in range(len(search_query_list)):
        params = {
            'q':search_query_list[query_index],
            'cp':3,
            'client':client,
            'hl':"{0}-{1}".format(language, country_code),
            'authuser':0,
            'dpr':1,
            }
        resp = requests.get("https://www.google.com/complete/search", params = params, headers=headers, timeout = 5)
        from posixpath import sep
        json_suggestions1 = resp.text.replace("window.google.ac.h(", "")
        json_suggestions1 =  json_suggestions1[:-1]
        try:
            final_tuple = json.loads(html_to_text(json_suggestions1.encode('ascii').decode('unicode-escape')))
        except:
            pass
        #print(final_tuple)
        if(query_index == 0):
            f = open("myfile.txt", "w")
        else:
            f = open("myfile.txt", "a")
        #print(final_tuple[0][0][0])
        #print(len(final_tuple[0]))

        list_of_outs = []

        for val in final_tuple[0]:
            no_of_vals = len(val)
            for n in range(no_of_vals):
                req_val = final_tuple[0][n][0]
                list_of_outs += [req_val]

        #print(list_of_outs)
        for values in list_of_outs:
            sp_val = values.split(' </b>')
            new = ' '.join(sp_val)
            if(new[-4:] != '</b>'):
                list_of_outs[list_of_outs.index(values)] = new
            else:
                list_of_outs[list_of_outs.index(values)] = new[:-4]

        list_of_outs = list(set(list_of_outs))
        list_of_outs.sort()

        ind = 0

        
        #list_of_outs[0][:len(search_query_list[query_index])]==search_query_list[query_index]

        qer = ' '.join(search_query_list[query_index].split(inp)).strip()

        if(len(qer)>1):
            if(qer in list_of_outs[0]):
                print('\n\033[1m'+search_query_list[query_index]+'\033[0m\n')
                for out in list_of_outs:
                    if(out != search_query_list[query_index]):
                        print("\x1B[3m"+''.join(out.split('</b>'))+"\x1B[0m")
                    # Is it necessary the below line?
                    else:
                        pass
            else:
                print('\n\033[1m'+search_query_list[query_index]+'\033[0m\n')
                print("\x1B[3m"+'NO RESULTS FOUND'+"\x1B[0m")
        else:
            to_ch = list_of_outs[0].split(inp)[-1].strip()
            try:
                if(to_ch[0] == qer):
                    print('\n\033[1m'+search_query_list[query_index]+'\033[0m\n')
                    for out in list_of_outs:
                        print("\x1B[3m"+''.join(out.split('</b>'))+"\x1B[0m")
                else:
                    print('\n\033[1m'+search_query_list[query_index]+'\033[0m\n')
                    print("\x1B[3m"+'NO RESULTS FOUND'+"\x1B[0m")
            except:
                pass
    
    global counter
    counter += 1

    if(counter == 800):
        
        crt = datetime.now().strftime("%H:%M")
        req_crt = int(crt[:2])*60 + int(crt[3:])
        if(req_crt < req_time):
            counter = 0
            req_time = req_crt
        else:
            if((req_crt - req_time)//60 <3.5):
                time.sleep(150)
                req_time = req_crt
                counter = 1
            else:
                counter = 400
                req_time = req_crt

    # connect to google 

    from pytrends.request import TrendReq

    hostname = socket.gethostname()    
    IPAddr = socket.gethostbyname(hostname)

    time.sleep(5)

    try:
        pytrends = TrendReq(hl='en-US', tz=360, timeout=(10,25), retries = 2, backoff_factor=0.1)

    except:
        pytrends = TrendReq(hl='en-US', tz=360, timeout=(10,25),proxies=['https://'+IPAddr,'https://34.203.233.13:80','https://35.201.123.31:880','https://174.70.1.210','https://139.162.252.174','https://204.2.218.145','https://130.41.101.105','https://85.92.119.65'], retries=3, backoff_factor=0.1, requests_args={'verify':False})

    else:
        quit()

    kw_list = [inp] # list of keywords to get data 

    pytrends.build_payload(kw_list, cat=0, timeframe='today 12-m') 
    try:
        data_for_related_topics = pytrends.related_topics()
        rising_title = list(data_for_related_topics[inp]['rising']['topic_title'])
        rising_type = list(data_for_related_topics[inp]['rising']['topic_type'])

        print("\n\n\033[1mRelated Topic Titles And Types With Rising Interest\033[0m\n\n")

        for i in range(len(rising_title)):
            print('\x1B[3m' + rising_title[i] + ' - ' + rising_type[i] + '\x1B[0m')

        top_title = list(data_for_related_topics[inp]['top']['topic_title'])
        top_type = list(data_for_related_topics[inp]['top']['topic_type'])

        print('\n\n\033[1mTop Searched Related Topic Titles and Types\033[0m\n\n')

        for i in range(len(top_title)):
            print('\x1B[3m' + top_title[i] + ' - ' + top_type[i] + '\x1B[0m')
    except:
        pass

    try:
        data_for_related_queries = pytrends.related_queries()
        rising_query = list(data_for_related_queries[inp]['rising']['query'])
        rising_query_val = list(data_for_related_queries[inp]['rising']['value'])

        print("\n\n\033[1mRelated Queries With Rising Interest And Their Search Values\033[0m\n\n")

        for i in range(len(rising_query)):
            print('\x1B[3m' + rising_query[i] + ' - ' + str(rising_query_val[i]) + '\x1B[0m')

        top_query = list(data_for_related_queries[inp]['top']['query'])
        top_query_val = list(data_for_related_queries[inp]['top']['value'])

        print('\n\n\033[1mTop Searched Related Queries And Search Values\033[0m\n\n')

        for i in range(len(top_query)):
            print('\x1B[3m' + top_query[i] + ' - ' + str(top_query_val[i]) + '\x1B[0m')

        print('\n\n')

    except:
        pass

    data = pytrends.interest_over_time() 
    data = data.reset_index() 


    import plotly.express as px

    fig = px.line(data, x="date", y=inp, title='Keyword Web Search Interest Over Time')
    fig.show()

# %%
function_to_call_for_every_search()
# Out:
# Enter a keyword => computer system
# <ipython-input-2-02e00addf20d>:101: DeprecationWarning: invalid escape sequence '\/'
#   final_tuple = json.loads(html_to_text(json_suggestions1.encode('ascii').decode('unicode-escape')))
# how computer system
#
# how many types of computer system
# how to clean your computer system
# how to draw a computer system
#
# what computer system
#
# what computer system does cvs pharmacy use
# what computer system does the patient monitoring belong
#
# when computer system
#
# safety measures when using a computer system
# when a computer is switched on where is the operating system loaded
# when is computer system
#
# where computer system
#
# when a computer is switched on where is the operating system loaded
# where is the operating system in a computer
# where on a computer is the operating system generally stored
#
# are computer system
#
# are components of computer system
# are hardware components of computer system
# are the four components of a computer system
#
# is computer system
#
# is a computer system
# is memory a computer system
# is software computer system
# is the device a part of a computer system
#
# why computer system
#
# why is computer system maintenance
# why is computer system maintenance important
# why is computer system maintenance important essay
#
# can computer system
#
# can a computer system function without a cpu
# can be used to help troubleshoot a computer system
# canada post new computer system
#
# computer system a
#
# computer system analyst
# computer system analyst salary
# computer system architecture
# computer system architecture morris mano
#
# computer system b
#
# computer system background
# computer system block diagram
# computer system box
# computer system bus
#
# computer system c
#
# computer system class 11 notes
# computer system components
# computer system concept
#
# computer system d
#
# computer system definition
# computer system diagram
# computer system drawing
#
# computer system e
#
# computer system engineer salary
# computer system engineering
# computer system examples
#
# computer system f
#
# computer system full form
# computer system function
# computer system fundamentals
#
# computer system g
#
# computer system geeksforgeeks
# computer system generation
# computer system gif
#
# computer system h
#
# computer system hardware
# computer system hardware and software
# computer system hsn code
#
# computer system i
#
# computer system image
# computer system in hindi
# computer system information
# computer system institute
#
# computer system j
#
# computer system javatpoint
# computer system jobs
# computer system jss2
#
# computer system k
#
# computer system ke ghatak
# computer system ki visheshtaen
# computer system kya hai
#
# computer system l
#
# computer system language
# computer system life cycle
# computer system logo
#
# computer system m
#
# computer system maintenance
# computer system manager
# computer system meaning
#
# computer system n
#
# computer system name
# computer system notes
# computer system notes pdf
#
# computer system o
#
# computer system operation in os
# computer system operations
# computer system organization
#
# computer system p
#
# computer system parts
# computer system pdf
# computer system price
#
# computer system q
#
# computer system questions and answers
# computer system questions and answers pdf
# computer system quiz
#
# computer system r
#
# computer system requirements
# computer system resources
# computer system restore
#
# computer system s
#
# computer system security
# computer system servicing
# computer system servicing nc ii
#
# computer system t
#
# computer system technician course details
# computer system types
# computer systems technician
#
# computer system u
#
# computer system unit
# computer system unit parts
# computer system unit parts and functions
#
# computer system v
#
# computer system validation
# computer system validation in pharma
# computer system validation jobs
#
# computer system w
#
# computer system watts
# computer system wikipedia
# computer system work
#
# computer system x
#
# computer system x64
# the icon x on the computer system means
# xerox alto computer system
#
# computer system y
#
# computer system youtube
# how to clean your computer system
# why does your computer need an operating system
#
# computer system z
#
# computer system zamboanga contact number
# lenin computer system zamboanga city
# zylux multimedia computer speaker system
#
#
# Related Topic Titles And Types With Rising Interest
#
#
# Science - School category
# Accounting - Professional field
#
#
# Top Searched Related Topic Titles and Types
#
#
# Computer - Topic
# System - Topic
# Operating system - Topic
# Software - Software grouping
# used - Topic
# Data - Topic
# Computer hardware - Topic
# Information - Topic
# Computer network - Topic
# Computer program - Topic
# Computer Application - Software classification
# Microsoft Windows - Operating system
# Computer file - Topic
# Computer data storage - Topic
# Central processing unit - Topic
# User - Computing
# Definition - Topic
# Computer memory - Topic
# Science - School category
# System software - Topic
# Computer Science - Field of study
# Function - Mathematics
# Management - Topic
# Internet - Topic
# Computer monitor - Topic
#
#
# Related Queries With Rising Interest And Their Search Values
#
#
# some wsl system related access rights are not set correctly. this sometimes happens after waking the computer or not being connected to your domain/active directory. please try to reboot the computer. if not sufficient, wsl may need to be reinstalled fully. as a last resort, try to uninstall/reinstall docker desktop. - 3750
# which kind of system software tells the computer how to communicate with peripherals, such as a printer or scanner? - 200
# operating system kya hai - 160
# paraphrasing tool - 150
# computer system servicing nc ii - 130
# computer system architecture in os - 90
# domain name system in computer networks - 70
# computer architecture - 60
#
#
# Top Searched Related Queries And Search Values
#
#
# in - 100
# system in computer - 97
# is - 94
# the - 92
# and - 77
# what - 68
# what is computer system - 61
# what is - 60
# what is system - 60
# what is computer - 59
# what is system in computer - 45
# which - 43
# computer operating system - 42
# what is a computer system - 42
# operating system - 42
# operating - 42
# what is a computer - 41
# what is a system - 40
# how - 33
# computer software - 32
# what is a system in computer - 32
# system software - 31
# software - 31
# operating system of computer - 29
# data - 28
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="1437837d-e11f-4d72-9060-cde86bff3bab" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1437837d-e11f-4d72-9060-cde86bff3bab")) {                    Plotly.newPlot(                        "1437837d-e11f-4d72-9060-cde86bff3bab",                        [{"hovertemplate":"date=%{x}<br>computer system=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2022-02-20T00:00:00","2022-02-27T00:00:00","2022-03-06T00:00:00","2022-03-13T00:00:00","2022-03-20T00:00:00","2022-03-27T00:00:00","2022-04-03T00:00:00","2022-04-10T00:00:00","2022-04-17T00:00:00","2022-04-24T00:00:00","2022-05-01T00:00:00","2022-05-08T00:00:00","2022-05-15T00:00:00","2022-05-22T00:00:00","2022-05-29T00:00:00","2022-06-05T00:00:00","2022-06-12T00:00:00","2022-06-19T00:00:00","2022-06-26T00:00:00","2022-07-03T00:00:00","2022-07-10T00:00:00","2022-07-17T00:00:00","2022-07-24T00:00:00","2022-07-31T00:00:00","2022-08-07T00:00:00","2022-08-14T00:00:00","2022-08-21T00:00:00","2022-08-28T00:00:00","2022-09-04T00:00:00","2022-09-11T00:00:00","2022-09-18T00:00:00","2022-09-25T00:00:00","2022-10-02T00:00:00","2022-10-09T00:00:00","2022-10-16T00:00:00","2022-10-23T00:00:00","2022-10-30T00:00:00","2022-11-06T00:00:00","2022-11-13T00:00:00","2022-11-20T00:00:00","2022-11-27T00:00:00","2022-12-04T00:00:00","2022-12-11T00:00:00","2022-12-18T00:00:00","2022-12-25T00:00:00","2023-01-01T00:00:00","2023-01-08T00:00:00","2023-01-15T00:00:00","2023-01-22T00:00:00","2023-01-29T00:00:00","2023-02-05T00:00:00"],"xaxis":"x","y":[97,89,100,85,84,82,77,68,81,79,67,70,71,77,72,73,72,74,73,73,57,69,64,58,51,55,72,71,76,85,89,78,76,82,77,64,71,71,72,68,73,72,76,56,50,56,64,69,64,70,66],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"] ...
